# %% [markdown]
# # Import libraries and define sheet

# %%
##def reset_cards(df):
##    df["Box"] = 1
##    df["Last Review"] = None
##    df["Next Review"] = None
##    df.to_excel(sheet, index=False)


##eset_cards(df)

# %%
import customtkinter as ctk
import pandas as pd
import random
from datetime import datetime, timedelta

sheet = "250_most_frequent_german_words_danish.xlsx"

df = pd.read_excel(sheet)

df["Last Review"] = pd.to_datetime(df["Last Review"], errors="coerce")
df["Next Review"] = pd.to_datetime(df["Next Review"], errors="coerce")

# %% [markdown]
# # Reset all cards to box 1

# %%
now = datetime.today().replace(microsecond=0)

df["Box"] = 1
df["Last Review"] = now
df["Next Review"] = now

df.to_excel(sheet, index=False)

# %% [markdown]
# # Define functions

# %%
# this function moves a card to the right and updates review date
def move_card_right(df, card_id):
    if df.at[card_id, "Box"] < 5:
        df.at[card_id, "Box"] += 1
        update_review_dates(df, card_id)
        df.to_excel(sheet)

# this function moves a card to the left and updates review date
def move_card_left(df, card_id):
    if df.at[card_id, "Box"] > 1:
        df.at[card_id, "Box"] -= 1
        update_review_dates(df, card_id)
        df.to_excel(sheet)
    elif df.at[card_id, "Box"] == 1:
        update_review_dates(df, card_id)
        df.to_excel(sheet)

#this functions takes the box number and returns the date of next review
def calculate_next_review(box):
    today = datetime.today().replace(microsecond=0)
    if box == 1:
        return today + timedelta(days=1)
    elif box == 2:
        return today + timedelta(days=2)
    elif box == 3:
        return today + timedelta(weeks=1)
    elif box == 4:
        return today + timedelta(weeks=2)
    elif box == 5:
        return today + timedelta(weeks=4)
    else:
        return today

#this function uses the calculated review date updates updates the dataFrame
def update_review_dates(df, card_id):
    today = datetime.today().replace(microsecond=0)  # remove microseconds
    df.at[card_id, "Last Review"] = today
    current_box = df.at[card_id, "Box"]
    df.at[card_id, "Next Review"] = calculate_next_review(current_box)

def draw_card():
    now = datetime.today().replace(microsecond=0)

    while True:
        due_cards = df[
            (df["Next Review"].isna()) |
            (df["Next Review"] <= now)
        ]

        if due_cards.empty:
            stackStatus = "empty"
            break

        idx = random.choice(due_cards.index.tolist())
        card = df.loc[idx]

        while True:
            user_input = input("Was it correct or incorrect? (r/f): ").lower()
            if user_input == "r":
                move_card_right(df, idx)
                break
            elif user_input == "f":
                move_card_left(df, idx)
                break
            else:
                print("Invalid input, type 'r' for right or 'f' for fail.")

# %% [markdown]
# # Take random cards from due boxes

# %%
# window
window = ctk.CTk()
window.title('Leitner App')
window.geometry('600x400')

# widgets
string_var = ctk.StringVar(value = 'a custom string')
label = ctk.CTkLabel(
	window,
	text = 'A ctk label',
	fg_color = ('blue','red'),
	text_color = ('black','white'),
	corner_radius = 10,
	textvariable = string_var)
label.pack()

button = ctk.CTkButton(
	window,
	text = 'A ctk button',
	fg_color = '#FF0',
	text_color = '#000',
	hover_color = '#AA0',
	command = lambda: draw_card(df)
button.pack()

frame = ctk.CTkFrame(window)
frame.pack()

slider = ctk.CTkSlider(frame)
slider.pack(padx = 20, pady = 20)

# exercise
switch = ctk.CTkSwitch(
	window,
	text = 'Exercise Switch',
	fg_color = ('blue','red'),
	progress_color = 'pink',
	button_color = 'green',
	button_hover_color = 'yellow',
	switch_width = 60,
	switch_height = 30,
	corner_radius = 2)
switch.pack()

# run
window.mainloop()
# Out:
# 2026-02-17 16:07:11.659 Python[73992:2640063] +[IMKClient subclass]: chose IMKClient_Legacy
# 2026-02-17 16:07:11.659 Python[73992:2640063] +[IMKInputSession subclass]: chose IMKInputSession_Legacy

# %%
def draw_card()

now = datetime.today().replace(microsecond=0)

while True:
    due_cards = df[
        (df["Next Review"].isna()) |
        (df["Next Review"] <= now)
    ]

    if due_cards.empty:
        print("No cards are due for review yet.")
        break

    idx = random.choice(due_cards.index.tolist())
    card = df.loc[idx]

    print(card["Question"])
    input("Press Enter to see the answer...")
    print(card["Answer"])

    while True:
        user_input = input("Was it correct or incorrect? (r/f): ").lower()
        if user_input == "r":
            move_card_right(df, idx)
            break
        elif user_input == "f":
            move_card_left(df, idx)
            break
        else:
            print("Invalid input, type 'r' for right or 'f' for fail.")
# Out:
# gjorde
# tat
# sætning
# satz
# Invalid input, type 'r' for right or 'f' for fail.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 23
#      20 print(card["Answer"])
#      22 while True:
# ---> 23     user_input = input("Was it correct or incorrect? (r/f): ").lower()
#      24     if user_input == "r":
#      25         move_card_right(df, idx)
#
# File ~/Documents/PythonProjects/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/Documents/PythonProjects/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
